# %% [markdown]
# ## Using Python to perform regressions on all possible independent variable subsets
#
# Kenneth Burchfiel
#
# First uploaded to GitHub on 2021-03-19
#
# MIT license (gov_data_compilation_3.csv dataset is in the public domain)

# %% [markdown]
# This program analyzes what combination of 7 independent variables may best explain differences among U.S. states in domestic (i.e. state-to-state) migration rates in 2018. The 7 variables, obtained from federal government data and thus believed to be in the public domain, are as follows:
#
# 1. 'rpp_2018' (regional price parities, which I understand to be a measure of the relative cost of of living in different states)
#
# 2. 'unemployment_2018' (the 2018 unemployment rate)
#
# 3. '2016_trump_vote', (what percent of votes in the 2016 presidential election in that state were for Donald Trump)
#
# 4. 'gdp_pct_change_2017_2018' (the percentage change in that state's gross domestic product from 2017 to 2018)
#
# 5. 'personal_income_per_capita_pct_change_2017_2018',
#
# 6. 'married_couple_families_as_share_of_households_2018',
#
# 7. 'fertility_rate_per_1000_2018'
#
#
# Although the findings from this regression are interesting, the main purpose of this program is to demonstrate how Python can make it both easier and faster to perform lots of regressions on a set of variables. The program accomplishes the following steps:
#
# Step 1: Read a CSV file (containing 7 independent variables) into a Pandas DataFrame.
#
# Step 2: Find all possible combinations of those variables that can be entered into a linear regression
#
# Step 3: Perform a linear regression on each of those variables, and append the regression output to a new list
#
# Step 4: Convert that list into a DataFrame, allowing the different models to be compared

# %% [markdown]
# ## Step 1

# %%
import pandas as pd
import statsmodels.api as sm
df_states = pd.read_csv('gov_data_compilation_3.csv',index_col='State') # gov_data_compilation_3.csv contains various statistics accessed from federal government sources (the Bureau of Economic Analysis; the Federal Election Commission; the US Census Bureau; and the Bureau of Labor Statistics). Because they were created by the U.S. government, I believe they are all in the public domain.
df_states
# Out:
#                       rpp_2018  unemployment_2018  2016_trump_vote  \
# State
# Alabama                   85.9                3.9         0.620831
# Alaska                   105.7                5.9         0.512815
# Arizona                   96.4                4.8         0.486716
# Arkansas                  84.7                3.7         0.605719
# California               116.2                4.3         0.316171
# Colorado                 101.3                3.0         0.432510
# Connecticut              105.5                3.9         0.409269
# Delaware                  98.7                3.7         0.417127
# District of Columbia     115.2                5.7         0.040875
# Florida                  100.7                3.6         0.490219
# Georgia                   93.1                4.0         0.507713
# Hawaii                   118.5                2.4         0.300387
# Idaho                     92.0                2.8         0.592614
# Illinois                  97.8                4.4         0.387618
# Indiana                   89.2                3.4         0.569400
# Iowa                      89.4                2.6         0.511473
# Kansas                    90.0                3.3         0.566546
# Kentucky                  87.5                4.2         0.625196
# Louisiana                 88.5                4.8         0.580887
# Maine                    100.6                3.1         0.448698
# Maryland                 107.7                3.8         0.339093
# Massachusetts            110.3                3.4         0.328084
# Michigan                  92.3                4.2         0.474976
# Minnesota                 97.7                3.0         0.449248
# Mississippi               85.6                5.0         0.579410
# Missouri                  88.7                3.2         0.567723
# Montana                   92.9                3.8         0.561685
# Nebraska                  89.6                2.9         0.587474
# Nevada                    96.8                4.4         0.455007
# New Hampshire            106.4                2.6         0.464587
# New Jersey               116.1                4.0         0.413504
# New Mexico                90.5                4.9         0.400425
# New York                 116.7                4.1         0.365156
# North Carolina            91.7                4.0         0.498281
# North Dakota              90.7                2.5         0.629556
# Ohio                      88.5                4.5         0.516877
# Oklahoma                  87.7                3.3         0.653229
# Oregon                   101.8                4.0         0.390940
# Pennsylvania              97.1                4.4         0.481833
# Rhode Island              99.9                4.1         0.388981
# South Carolina            91.0                3.4         0.549393
# South Dakota              88.1                2.9         0.615308
# Tennessee                 89.3                3.5         0.607220
# Texas                     96.5                3.9         0.522347
# Utah                      96.0                2.9         0.455380
# Vermont                  103.7                2.6         0.302694
# Virginia                 101.6                2.9         0.444067
# Washington               108.6                4.4         0.368327
# West Virginia             87.7                5.2         0.684988
# Wisconsin                 91.9                3.0         0.472182
# Wyoming                   92.3                4.0         0.681726
#
#                       gdp_pct_change_2017_2018  \
# State
# Alabama                               2.251346
# Alaska                                0.194602
# Arizona                               3.938298
# Arkansas                              1.520739
# California                            3.068594
# Colorado                              4.369849
# Connecticut                           0.389476
# Delaware                              2.120415
# District of Columbia                  2.038917
# Florida                               3.844846
# Georgia                               3.711253
# Hawaii                                1.436830
# Idaho                                 5.910057
# Illinois                              2.282117
# Indiana                               2.844698
# Iowa                                  2.289194
# Kansas                                2.418867
# Kentucky                              1.574533
# Louisiana                             2.710698
# Maine                                 2.390793
# Maryland                              0.807255
# Massachusetts                         3.449337
# Michigan                              2.292926
# Minnesota                             2.914052
# Mississippi                           0.979503
# Missouri                              1.945111
# Montana                               2.521735
# Nebraska                              1.172440
# Nevada                                4.228750
# New Hampshire                         2.574555
# New Jersey                            1.543346
# New Mexico                            2.286747
# New York                              2.959586
# North Carolina                        2.643701
# North Dakota                          4.253361
# Ohio                                  2.263408
# Oklahoma                              2.682597
# Oregon                                4.627608
# Pennsylvania                          1.911565
# Rhode Island                          0.773408
# South Carolina                        3.142449
# South Dakota                          2.744444
# Tennessee                             2.689186
# Texas                                 3.869700
# Utah                                  5.577390
# Vermont                               0.863116
# Virginia                              2.287763
# Washington                            7.161707
# West Virginia                         3.033271
# Wisconsin                             3.268960
# Wyoming                               2.191923
#
#                       personal_income_per_capita_pct_change_2017_2018  \
# State
# Alabama                                                      3.848464
# Alaska                                                       5.231292
# Arizona                                                      4.297047
# Arkansas                                                     4.317724
# California                                                   4.862066
# Colorado                                                     5.217697
# Connecticut                                                  4.068240
# Delaware                                                     3.727372
# District of Columbia                                         2.310227
# Florida                                                      4.205504
# Georgia                                                      3.678111
# Hawaii                                                       3.423834
# Idaho                                                        4.624130
# Illinois                                                     4.960670
# Indiana                                                      4.315262
# Iowa                                                         6.542134
# Kansas                                                       5.010586
# Kentucky                                                     3.345070
# Louisiana                                                    5.168902
# Maine                                                        3.990615
# Maryland                                                     2.492151
# Massachusetts                                                4.282535
# Michigan                                                     3.616966
# Minnesota                                                    4.602698
# Mississippi                                                  3.890408
# Missouri                                                     3.853271
# Montana                                                      4.326635
# Nebraska                                                     4.893357
# Nevada                                                       5.231351
# New Hampshire                                                3.843768
# New Jersey                                                   3.950968
# New Mexico                                                   5.152767
# New York                                                     2.577175
# North Carolina                                               4.117804
# North Dakota                                                 8.282116
# Ohio                                                         4.089282
# Oklahoma                                                     4.430181
# Oregon                                                       4.930725
# Pennsylvania                                                 5.019455
# Rhode Island                                                 2.964527
# South Carolina                                               4.074707
# South Dakota                                                 8.438330
# Tennessee                                                    4.198332
# Texas                                                        4.873756
# Utah                                                         5.457485
# Vermont                                                      3.502637
# Virginia                                                     3.968409
# Washington                                                   5.583841
# West Virginia                                                6.263909
# Wisconsin                                                    4.613723
# Wyoming                                                      6.712433
#
#                       married_couple_families_as_share_of_households_2018  \
# State
# Alabama                                                           0.474
# Alaska                                                            0.502
# Arizona                                                           0.477
# Arkansas                                                          0.479
# California                                                        0.494
# Colorado                                                          0.491
# Connecticut                                                       0.472
# Delaware                                                          0.473
# District of Columbia                                              0.254
# Florida                                                           0.466
# Georgia                                                           0.469
# Hawaii                                                            0.516
# Idaho                                                             0.545
# Illinois                                                          0.471
# Indiana                                                           0.480
# Iowa                                                              0.491
# Kansas                                                            0.504
# Kentucky                                                          0.484
# Louisiana                                                         0.431
# Maine                                                             0.468
# Maryland                                                          0.483
# Massachusetts                                                     0.467
# Michigan                                                          0.467
# Minnesota                                                         0.503
# Mississippi                                                       0.444
# Missouri                                                          0.476
# Montana                                                           0.494
# Nebraska                                                          0.496
# Nevada                                                            0.433
# New Hampshire                                                     0.516
# New Jersey                                                        0.512
# New Mexico                                                        0.434
# New York                                                          0.440
# North Carolina                                                    0.479
# North Dakota                                                      0.468
# Ohio                                                              0.451
# Oklahoma                                                          0.482
# Oregon                                                            0.484
# Pennsylvania                                                      0.476
# Rhode Island                                                      0.430
# South Carolina                                                    0.465
# South Dakota                                                      0.498
# Tennessee                                                         0.479
# Texas                                                             0.498
# Utah                                                              0.609
# Vermont                                                           0.470
# Virginia                                                          0.497
# Washington                                                        0.502
# West Virginia                                                     0.473
# Wisconsin                                                         0.485
# Wyoming                                                           0.507
#
#                       fertility_rate_per_1000_2018  \
# State
# Alabama                                         58
# Alaska                                          62
# Arizona                                         57
# Arkansas                                        57
# California                                      47
# Colorado                                        52
# Connecticut                                     44
# Delaware                                        47
# District of Columbia                            41
# Florida                                         49
# Georgia                                         47
# Hawaii                                          59
# Idaho                                           59
# Illinois                                        53
# Indiana                                         58
# Iowa                                            58
# Kansas                                          63
# Kentucky                                        56
# Louisiana                                       57
# Maine                                           51
# Maryland                                        50
# Massachusetts                                   44
# Michigan                                        51
# Minnesota                                       60
# Mississippi                                     50
# Missouri                                        58
# Montana                                         50
# Nebraska                                        58
# Nevada                                          52
# New Hampshire                                   46
# New Jersey                                      51
# New Mexico                                      51
# New York                                        46
# North Carolina                                  48
# North Dakota                                    66
# Ohio                                            55
# Oklahoma                                        56
# Oregon                                          47
# Pennsylvania                                    51
# Rhode Island                                    43
# South Carolina                                  55
# South Dakota                                    59
# Tennessee                                       53
# Texas                                           54
# Utah                                            66
# Vermont                                         42
# Virginia                                        49
# Washington                                      52
# West Virginia                                   49
# Wisconsin                                       53
# Wyoming                                         65
#
#                       domestic_migration_rate_2018  pop_pct_chg_2017_2018
# State
# Alabama                                   1.081522               0.270695
# Alaska                                  -14.587355              -0.616601
# Arizona                                  11.845206               1.618624
# Arkansas                                  0.763257               0.279475
# California                               -3.940138               0.261928
# Colorado                                  7.526914               1.414890
# Connecticut                              -6.711439              -0.049730
# Delaware                                  7.127912               0.904661
# District of Columbia                     -0.455440               0.955669
# Florida                                   6.422016               1.339006
# Georgia                                   3.822008               0.968279
# Hawaii                                   -9.075616              -0.266780
# Idaho                                    13.851362               1.910736
# Illinois                                 -8.916905              -0.436323
# Indiana                                   0.605681               0.562009
# Iowa                                     -1.557669               0.224984
# Kansas                                   -3.973831               0.090796
# Kentucky                                  0.050710               0.199561
# Louisiana                                -5.953967              -0.232734
# Maine                                     4.314670               0.333056
# Maryland                                 -4.038751               0.198112
# Massachusetts                            -3.961892               0.333042
# Michigan                                 -1.667470               0.109875
# Minnesota                                 1.175388               0.718961
# Mississippi                              -4.950138              -0.250627
# Missouri                                 -0.441108               0.244863
# Montana                                   5.674948               0.777495
# Nebraska                                 -1.735753               0.504555
# Nevada                                   15.890627               1.933934
# New Hampshire                             2.060504               0.346830
# New Jersey                               -5.756504               0.005627
# New Mexico                               -2.506378               0.045750
# New York                                 -9.266992              -0.302309
# North Carolina                            6.965184               1.104202
# North Dakota                             -3.116941               0.415661
# Ohio                                     -1.052537               0.143152
# Oklahoma                                 -1.119983               0.226871
# Oregon                                    6.645358               0.923370
# Pennsylvania                             -1.620333               0.103858
# Rhode Island                             -2.619728               0.247615
# South Carolina                            9.960987               1.252433
# South Dakota                              0.759321               0.667913
# Tennessee                                 6.133484               0.936561
# Texas                                     2.944104               1.178264
# Utah                                      5.142781               1.693237
# Vermont                                  -0.286698               0.002242
# Virginia                                 -1.098387               0.445426
# Washington                                6.309262               1.353928
# West Virginia                            -4.411129              -0.699668
# Wisconsin                                -0.150204               0.297400
# Wyoming                                  -6.618062              -0.229734

# %%
df_states.dtypes # Confirms that all the variables are numerical in nature, which is important for the regression analysis
# Out:
# rpp_2018                                               float64
# unemployment_2018                                      float64
# 2016_trump_vote                                        float64
# gdp_pct_change_2017_2018                               float64
# personal_income_per_capita_pct_change_2017_2018        float64
# married_couple_families_as_share_of_households_2018    float64
# fertility_rate_per_1000_2018                             int64
# domestic_migration_rate_2018                           float64
# pop_pct_chg_2017_2018                                  float64
# dtype: object

# %% [markdown]
# ## Step 2

# %% [markdown]
# I will next create a function that, given 7 independent variables, produces all possible subsets of those variables, then adds those subsets (except for the empty subset) to a list. Since each variable can either be included or not included (2 possible conditions), the total number of non-empty subsets = 2^7 -1 = 127.
#
# The function uses a series of for loops to store 2 different values (0 and 1) in 7 different variables (include_var_1, include_var_2 . . . include_var_7). Within those sets, if a variable equals 1, its corresponding DataFrame variable will be included in a list (var_list). Each var_list with at least one item will then be added to another list (subset_list).
#
# To better visualize the function's output, here are the different lists of include_var values that would be created if there were only 3 variables (A, B, and C). I also included the subset of variables that would correspond to each list.
#
#     include_var_0 = 1
#
#         include_var_1 = 1
#
#             include_var_2 = 1
#
#                 [Output: 1, 1, 1]
#
#                 [Corresopnding variable list: A, B, C]
#
#             include_var_2 = 0
#
#                 [Output: 1, 1, 0]
#
#                 [Corresopnding variable list: A, B]
#
#         include_var_1 = 0
#
#             include_var_2 = 1
#
#                 [Output: 1, 0, 1]
#
#                 [Corresopnding variable list: A, C]
#
#             include_var_2 = 0
#
#                 [Output: 1, 0, 0]
#
#                 [Corresopnding variable list: A]
#
#     include_var_0 = 0
#
#         include_var_1 = 1
#
#                 include_var_2 = 1
#
#                     [Output: 0, 1, 1]
#
#                     [Corresopnding variable list: B, C]
#
#                 include_var_2 = 0
#
#                     [Output: 0, 1, 0]
#
#                     [Corresopnding variable list: B]
#
#             include_var_1 = 0
#
#                 include_var_2 = 1
#
#                     [Output: 0, 0, 1]
#
#                     [Corresopnding variable list: C]
#
#                 include_var_2 = 0
#
#                     [Output: 0, 0, 0]
#
#                     [Corresopnding variable list: [] (not included)]
#
#
#
#
# A disadvantage to this function is that it is hard-coded for 7 variables. I imagine that there is a way to create a recursive function that allows for all subsets of an arbitrarily long set of variables to be created. However, I will use the hard-coded strategy for now.

# %%
def create_7_var_list_subsets(variable_list): 
    subset_list = []
    for include_var_0 in range (2): # Creates two conditions: include_var_0 = 1, and include_var_0 = 0
        for include_var_1 in range (2):
            for include_var_2 in range (2):
                for include_var_3 in range (2):
                    for include_var_4 in range (2):
                        for include_var_5 in range (2):
                            for include_var_6 in range (2):
                                var_list = [] # This list will store the variable subset for this particular result of the 7 for loops.
                                if include_var_0 == 1:
                                    var_list.append(variable_list[0])
                                if include_var_1 == 1:
                                    var_list.append(variable_list[1])
                                if include_var_2 == 1:
                                    var_list.append(variable_list[2])
                                if include_var_3 == 1:
                                    var_list.append(variable_list[3])
                                if include_var_4 == 1:
                                    var_list.append(variable_list[4])
                                if include_var_5 == 1:
                                    var_list.append(variable_list[5])
                                if include_var_6 == 1:
                                    var_list.append(variable_list[6])                                  
                                # print(var_list) for debugging
                                if len(var_list) > 0: # Excludes the empty subset
                                # from the subset list
                                    subset_list.append(var_list) # Adds this particular subset to the overall list of subsets
    return subset_list

# %% [markdown]
# Next, I will use a list of my DataFrame's columns to create a list of 7 independent variables that can be entered into the create_7_var_list_subsets function.

# %%
ind_variables_list=[]
for i in range(7):
    ind_variables_list.append(df_states.columns[i])
ind_variables_list # Prints out the list of 7 independent variables
# Out:
# ['rpp_2018',
#  'unemployment_2018',
#  '2016_trump_vote',
#  'gdp_pct_change_2017_2018',
#  'personal_income_per_capita_pct_change_2017_2018',
#  'married_couple_families_as_share_of_households_2018',
#  'fertility_rate_per_1000_2018']

# %% [markdown]
# I will now create all possible subsets of these 7 independent variables using the create_7_var_list_subsets function.

# %%
ind_regression_models = create_7_var_list_subsets(ind_variables_list)
for model in ind_regression_models:
    print(model)                 
print(len(ind_regression_models)) # Verifies that 127 (2^7 - 1) models have been created
# Out:
# ['fertility_rate_per_1000_2018']
# ['married_couple_families_as_share_of_households_2018']
# ['married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['personal_income_per_capita_pct_change_2017_2018']
# ['personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['gdp_pct_change_2017_2018']
# ['gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote']
# ['2016_trump_vote', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'married_couple_families_as_share_of_households_2018']
# ['2016_trump_vote', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018']
# ['2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018']
# ['unemployment_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote']
# ['unemployment_2018', '2016_trump_vote', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018']
# ['unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018']
# ['rpp_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote']
# ['rpp_2018', '2016_trump_vote', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018']
# ['rpp_2018', 'unemployment_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'fertility_rate_per_1000_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018']
# ['rpp_2018', 'unemployment_2018', '2016_trump_vote', 'gdp_pct_change_2017_2018', 'personal_income_per_capita_pct_change_2017_2018', 'married_couple_families_as_share_of_households_2018', 'fertility_rate_per_1000_2018']
# 127

# %% [markdown]
# ## Step 3

# %% [markdown]
# The following function takes a list of independent variable subsets; performs a linear regression on each one; stores various elements of that regression output into a dictionary; and appends that dictionary into a list of dictionaries.

# %%
def subset_regressions(subset_list, dv, df):
    regression_dict_list = []
    for i in range(len(subset_list)):
            y = dv
            x = df[subset_list[i]] # This method of adding a list of IVs is based on a Stack Overflow answer by unutbu: https://stackoverflow.com/a/29186780/13097194
            x = sm.add_constant(x)
            output = sm.OLS(y,x)
            results = output.fit()
            regression_dict = {}
            regression_dict['IVs']=subset_list[i] # Stores the list of independent variables used in the regression into the dictionary
            regression_dict['rsquared']=results.rsquared
            regression_dict['adj_rsquared']=results.rsquared_adj
            regression_dict['summary']=results.summary()
            regression_dict_list.append(regression_dict)
    return regression_dict_list

# %% [markdown]
# ## Step 4

# %% [markdown]
# I will now enter the list of independent variable subsets created earlier into the subset_regression function.

# %%
regression_dv = df_states['domestic_migration_rate_2018'] # Using the 2018 domestic migration rate as the dependent variable
regression_table = subset_regressions(ind_regression_models,regression_dv,df_states)
df_regressions = pd.DataFrame(regression_table) # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
pd.set_option('display.max_rows',150)
df_regressions.head(10) # Listed in the order the regressions were generated
# Out:
#                                                  IVs  rsquared  adj_rsquared  \
# 0                     [fertility_rate_per_1000_2018]  0.002458     -0.017900
# 1  [married_couple_families_as_share_of_household...  0.007845     -0.012403
# 2  [married_couple_families_as_share_of_household...  0.019533     -0.021320
# 3  [personal_income_per_capita_pct_change_2017_2018]  0.000004     -0.020404
# 4  [personal_income_per_capita_pct_change_2017_20...  0.003735     -0.037776
# 5  [personal_income_per_capita_pct_change_2017_20...  0.008665     -0.032640
# 6  [personal_income_per_capita_pct_change_2017_20...  0.020229     -0.042309
# 7                         [gdp_pct_change_2017_2018]  0.379965      0.367311
# 8  [gdp_pct_change_2017_2018, fertility_rate_per_...  0.404940      0.380145
# 9  [gdp_pct_change_2017_2018, married_couple_fami...  0.385675      0.360078
#
#                                              summary
# 0                                   OLS Regressio...
# 1                                   OLS Regressio...
# 2                                   OLS Regressio...
# 3                                   OLS Regressio...
# 4                                   OLS Regressio...
# 5                                   OLS Regressio...
# 6                                   OLS Regressio...
# 7                                   OLS Regressio...
# 8                                   OLS Regressio...
# 9                                   OLS Regressio...

# %% [markdown]
# I will now sort this table of regressions in descending order by their adjusted r-squared in order to see which subsets may best explain the variation in the 2018 U.S. domestic migration rate.
#
# *Note: I say 'may explain' because there is always a risk of conflating correlation with causation. It is possible that the independent variables can help explain the domestic migration rate; however, it is also possible that the domestic migraiton rate instead plays a role in determining the independent variables, or that some third variable is behind the relationship between each independent variable and the dependent variable.*

# %%
df_regressions.sort_values('adj_rsquared', ascending=False, inplace=True)
df_regressions.head()
# Out:
#                                                    IVs  rsquared  \
# 108  [rpp_2018, unemployment_2018, gdp_pct_change_2...  0.603244
# 124  [rpp_2018, unemployment_2018, 2016_trump_vote,...  0.606293
# 110  [rpp_2018, unemployment_2018, gdp_pct_change_2...  0.603873
# 126  [rpp_2018, unemployment_2018, 2016_trump_vote,...  0.606295
# 76   [rpp_2018, gdp_pct_change_2017_2018, personal_...  0.572915
#
#      adj_rsquared                                            summary
# 108      0.559161                                   OLS Regressio...
# 124      0.552606                                   OLS Regressio...
# 110      0.549855                                   OLS Regressio...
# 126      0.542203                                   OLS Regressio...
# 76       0.535778                                   OLS Regressio...

# %% [markdown]
# Now that the table is sorted, the best-performing model, which happens to use 5 variables (rpp_2018; unemployment_2018; gdp_pct_change_2017_2018; personal_income_per_capita_pct_change_2017_2018; and fertility_rate_per_1000_2018) is at the top. The following line accesses the statsmodels summary output for that model.

# %%
df_regressions.iloc[0,3]
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     domestic_migration_rate_2018   R-squared:                       0.603
# Model:                                      OLS   Adj. R-squared:                  0.559
# Method:                           Least Squares   F-statistic:                     13.68
# Date:                          Fri, 19 Mar 2021   Prob (F-statistic):           3.94e-08
# Time:                                  16:57:59   Log-Likelihood:                -140.64
# No. Observations:                            51   AIC:                             293.3
# Df Residuals:                                45   BIC:                             304.9
# Df Model:                                     5
# Covariance Type:                      nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              45.4524     11.623      3.911      0.000      22.042      68.863
# rpp_2018                                           -0.2921      0.072     -4.073      0.000      -0.436      -0.148
# unemployment_2018                                  -1.3526      0.729     -1.855      0.070      -2.821       0.116
# gdp_pct_change_2017_2018                            3.2564      0.455      7.156      0.000       2.340       4.173
# personal_income_per_capita_pct_change_2017_2018    -1.5053      0.615     -2.446      0.018      -2.745      -0.266
# fertility_rate_per_1000_2018                       -0.2565      0.121     -2.112      0.040      -0.501      -0.012
# ==============================================================================
# Omnibus:                        5.704   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                5.092
# Skew:                           0.493   Prob(JB):                       0.0784
# Kurtosis:                       4.193   Cond. No.                     2.27e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Finally, I will save this sorted table as a CSV file.

# %%
df_regressions.to_csv('domestic_migration_regressions.csv')

# %% [markdown]
# The regression results should be interpreted with caution for a number of reasons:
#
# 1. It is possible that the 5-variable model featured above performed the best out of all 127 due to random chance, and not because it is a valid predictor of variation in state migration rates. There is also a risk that the model has overfit to this particular dataset.
#
# In order to guard against this possibility, the program could be revised so that each model is trained on one portion of the data, then tested on another portion (i.e. using k-fold cross-validation).
#
# 2. This model may be less accurate for subsequent years (2019, 2020, etc.).
#
# 3. Correlation is no guarantee of causation, as discussed above.
#
#
# However, as noted earlier, the main purpose of this program is to demonstrate how Python makes it easy to perform hundreds of regressions in just seconds. It should not prove difficult to repurpose this program for other analyses.
